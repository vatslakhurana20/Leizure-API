# %%
# to handle  data retrieval
import urllib3
from urllib3 import request
# to handle certificate verification
import certifi
# to manage json data
import json
# for pandas dataframes
import pandas as pd
import numpy as np
# uncomment below if installation needed (not necessary in Colab)
#!pip install certifi

# %%
# handle certificate verification and SSL warnings
# https://urllib3.readthedocs.io/en/latest/user-guide.html#ssl
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())

# %%
# get data from the API
url = 'https://api.themoviedb.org/3/discover/movie?with_genres=27&with_original_language=hi|kn|ml|ta|te&api_key=d08aea0bd49352097d28659b824a26b6'
r = http.request('GET', url)
r.status
# Out:
# 200

# %%
# decode json data into a dict object
data = json.loads(r.data.decode('utf-8'))
data
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/kIszdVMM7Dezzrs0P7jUcMkG3o8.jpg',
#    'genre_ids': [27, 14],
#    'id': 714338,
#    'original_language': 'hi',
#    'original_title': 'Bulbbul',
#    'overview': 'A child bride grows up to be an enigmatic woman presiding over her household, harboring a painful past as supernatural murders of men plague her village.',
#    'popularity': 27.028,
#    'poster_path': '/4XYEqHqvcf6vxFhNyeKZz5xbUfV.jpg',
#    'release_date': '2020-06-24',
#    'title': 'Bulbbul',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 57},
#   {'adult': False,
#    'backdrop_path': '/dKSykSoV8eGWYqgmVJwBpBvTPzz.jpg',
#    'genre_ids': [27],
#    'id': 601643,
#    'original_language': 'hi',
#    'original_title': 'Ghost Stories',
#    'overview': 'An anthology of four short horror tales.',
#    'popularity': 8.424,
#    'poster_path': '/wuTwPYFoEGQG3EntpdZA8LlBBdx.jpg',
#    'release_date': '2020-01-01',
#    'title': 'Ghost Stories',
#    'video': False,
#    'vote_average': 4.7,
#    'vote_count': 38},
#   {'adult': False,
#    'backdrop_path': '/eJPky5hssaNpjVRS5XMB3gkgJrQ.jpg',
#    'genre_ids': [27, 35],
#    'id': 533991,
#    'original_language': 'hi',
#    'original_title': 'स्त्री',
#    'overview': 'Set in the town of Chanderi, Stree is based on the urban legend of Nale Ba that went viral in Karnataka in the 1990s, and features Shraddha Kapoor and Rajkummar Rao in pivotal roles.',
#    'popularity': 7.421,
#    'poster_path': '/vkbSB8U9uPN18ssXCf8taetBae.jpg',
#    'release_date': '2018-08-31',
#    'title': 'Stree',
#    'video': False,
#    'vote_average': 7,
#    'vote_count': 80},
#   {'adult': False,
#    'backdrop_path': '/lDiRA1SkMLVduOaOmn6V0vg3c0h.jpg',
#    'genre_ids': [35, 27, 53],
#    'id': 19025,
#    'original_language': 'hi',
#    'original_title': 'भूल भुलैया',
#    'overview': "When U.S.-based Siddharth visits his Indian home town with his new wife, he insists they stay at the ancestral home, laughing off family members' warnings of ghostly goings-on in the mansion. But events soon make him reconsider his beliefs. As unexplained and terrifying occurrences arise, Siddharth calls on his doctor friend to help solve the mystery. What will be the outcome? Will Siddharth's friend be able to solve this riddle?",
#    'popularity': 6.864,
#    'poster_path': '/soRW3p4GlPphHiFkwbqYGrodQ5S.jpg',
#    'release_date': '2007-10-12',
#    'title': 'Bhool Bhulaiyaa',
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 96},
#   {'adult': False,
#    'backdrop_path': '/ndO0KTkql6zr0u0cQ6gOsqpgpUd.jpg',
#    'genre_ids': [27, 14],
#    'id': 538858,
#    'original_language': 'hi',
#    'original_title': 'तुम्बाड',
#    'overview': 'India, 1918. On the outskirts of Tumbbad, a cursed village where it always rains, Vinayak, along with his mother and his brother, care of a mysterious old woman who keeps the secret of an ancestral treasure that Vinayak gets obsessed with.',
#    'popularity': 6.267,
#    'poster_path': '/5Q3Iz5YaGZVnvk3tjDDrW71iaym.jpg',
#    'release_date': '2018-10-12',
#    'title': 'Tumbbad',
#    'video': False,
#    'vote_average': 7.7,
#    'vote_count': 105},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [35, 27],
#    'id': 191562,
#    'original_language': 'hi',
#    'original_title': 'गो गोआ गॉन',
#    'overview': 'A rave party off the coast of Goa goes horrifyingly and hilariously wrong when the island is overrun with zombies.',
#    'popularity': 4.93,
#    'poster_path': '/5yArWoxijgN0gvo0ExQfKXgZ0Qr.jpg',
#    'release_date': '2013-05-10',
#    'title': 'Go Goa Gone',
#    'video': False,
#    'vote_average': 5.8,
#    'vote_count': 68},
#   {'adult': False,
#    'backdrop_path': '/hbVQ8B6k1XyRCa1aGQluyyT4LOX.jpg',
#    'genre_ids': [27, 53],
#    'id': 616880,
#    'original_language': 'hi',
#    'original_title': 'Bhoot: Part One - The Haunted Ship',
#    'overview': "When an abandoned haunted ship called 'Sea Bird' washes up on the shores of Mumbai, surveying officer Prithvi is assigned to solve the mystery and close the case",
#    'popularity': 4.693,
#    'poster_path': '/5rSRVvlIlelgKM58MAnnk4FId86.jpg',
#    'release_date': '2020-02-21',
#    'title': 'Bhoot: Part One - The Haunted Ship',
#    'video': False,
#    'vote_average': 6.6,
#    'vote_count': 15},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [35, 27],
#    'id': 330425,
#    'original_language': 'ta',
#    'original_title': 'காஞ்சனா 2',
#    'overview': 'A TV channel’s crew goes to a deserted beachside bungalow to stage a horror show but the place is actually haunted and the ghost(s) in the place possess the director and the cameraman in the team.',
#    'popularity': 4.609,
#    'poster_path': '/oBaVzegjQza23C1XCOMfnQRhplw.jpg',
#    'release_date': '2015-04-17',
#    'title': 'Kanchana 2',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 17},
#   {'adult': False,
#    'backdrop_path': '/2JTqYozAkCUga9LSq64gI9CJ8Bm.jpg',
#    'genre_ids': [35, 27, 28, 14],
#    'id': 472123,
#    'original_language': 'hi',
#    'original_title': 'गोलमाल अगेन',
#    'overview': 'Gopal and his best friends are back again, and this time they move back to their old neighborhood in a new palatial house where they learn that it is being haunted by a ghost.',
#    'popularity': 4.463,
#    'poster_path': '/kGx26PL1v658T8XbOk5MfmNpHU3.jpg',
#    'release_date': '2017-10-20',
#    'title': 'Golmaal Again',
#    'video': False,
#    'vote_average': 5.5,
#    'vote_count': 57},
#   {'adult': False,
#    'backdrop_path': '/2pGBScm9WFQhDRL0ZljVgbWdhWP.jpg',
#    'genre_ids': [18, 9648, 27],
#    'id': 19950,
#    'original_language': 'ta',
#    'original_title': 'யாவரும் நலம்',
#    'overview': "Manohar, an upwardly mobile middle class Indian moves into a new apartment -13B on the 13th floor with his family. From the first day in their new home, the women are hooked on to a new TV show 'Sab Khairiyat'. The show is about a family eerily similar to theirs who have also just moved into a new house. As the TV show unfolds, all the incidents that happen in the show start happening to them.",
#    'popularity': 4.427,
#    'poster_path': '/pb1Dm4lKpqdqXdsX1piIIiTaTGj.jpg',
#    'release_date': '2009-03-06',
#    'title': 'Yavarum Nalam',
#    'video': False,
#    'vote_average': 6.1,
#    'vote_count': 46},
#   {'adult': False,
#    'backdrop_path': '/lHyphBOFj1gv2Ykg5dmRtxWx92M.jpg',
#    'genre_ids': [27, 53],
#    'id': 553456,
#    'original_language': 'ta',
#    'original_title': 'கேம் ஓவர்',
#    'overview': 'Swapna, a nyctophobic game designer, is on a turbulent road to recovery from an incident that scarred her deeply, has to fight her inner demons to stay alive in the game called life.',
#    'popularity': 4.406,
#    'poster_path': '/wBUt6oTFZOMN1skbhIq0gpxpe6J.jpg',
#    'release_date': '2019-06-14',
#    'title': 'Game Over',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 39},
#   {'adult': False,
#    'backdrop_path': '/xbRIRQKKGJHEUB45AEH39ZCZNda.jpg',
#    'genre_ids': [14, 27, 9648, 53],
#    'id': 84368,
#    'original_language': 'ml',
#    'original_title': 'മണിച്ചിത്രത്താഴ്',
#    'overview': "A young couple, Ganga and Nakulan, arrives at the ancestral home called Madampalli of the latter. Hailing from a family that follows tradition and superstitions, Nakulan's uncle Thampi objects to the couple's idea of moving into the allegedly haunted mansion, which Nakulan ignores. The couple moves in anyway following which seemingly supernatural events begin to happen.",
#    'popularity': 4.388,
#    'poster_path': '/5YccrqvJFTfAVyEZp08I3fLx15y.jpg',
#    'release_date': '1993-12-25',
#    'title': 'Manichitrathazhu',
#    'video': False,
#    'vote_average': 7.6,
#    'vote_count': 52},
#   {'adult': False,
#    'backdrop_path': '/yCNnj1s6CoAOehejo27TV8gtOKe.jpg',
#    'genre_ids': [27, 35],
#    'id': 603673,
#    'original_language': 'hi',
#    'original_title': 'लक्ष्मी',
#    'overview': "Aasif's belief in logic and science shatters when he gets possessed by a transgender's ghost.",
#    'popularity': 4.18,
#    'poster_path': '/9sZ1UGVxOCs4yDd5NoACRkK0oXn.jpg',
#    'release_date': '2020-11-09',
#    'title': 'Laxmii',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 11},
#   {'adult': False,
#    'backdrop_path': '/iWpsVDT36YxGxxf23DUEwiHSBe0.jpg',
#    'genre_ids': [14, 27, 53],
#    'id': 47655,
#    'original_language': 'hi',
#    'original_title': 'Hisss',
#    'overview': 'Based on the Far Eastern myth of the snake woman who is able to take on human form.',
#    'popularity': 4.169,
#    'poster_path': '/iSCkImhJUgyagR7FxXxasXnNsDv.jpg',
#    'release_date': '2010-10-22',
#    'title': 'Hisss',
#    'video': False,
#    'vote_average': 3.7,
#    'vote_count': 26},
#   {'adult': False,
#    'backdrop_path': '/7GuYHiwBEnZ6ulinOOJAHLjlYRE.jpg',
#    'genre_ids': [14, 27],
#    'id': 371420,
#    'original_language': 'ta',
#    'original_title': 'காஷ்மோரா',
#    'overview': 'Kaashmora, a present era black magic specialist; Rajnayak, an ancient era warlord and Ratnamahadevi is his queen. How these three are connected? What are the issues that arise?',
#    'popularity': 4.028,
#    'poster_path': '/fhWdd4obIA9ASc7xYfo38JyLqpQ.jpg',
#    'release_date': '2016-10-28',
#    'title': 'Kaashmora',
#    'video': False,
#    'vote_average': 4.8,
#    'vote_count': 17},
#   {'adult': False,
#    'backdrop_path': '/qQGKo21qes7ZjsJqKSSnfUBghKM.jpg',
#    'genre_ids': [53, 27],
#    'id': 648705,
#    'original_language': 'te',
#    'original_title': 'నిశ్శబ్దం',
#    'overview': 'Seattle PD is investigating the murder of a man and Sakshi, a deaf and mute artist, and her husband Antony, a renowned cello player, are related to it.',
#    'popularity': 4.01,
#    'poster_path': '/mz4hwTvyU4AERcgZxY1rpL2A8sv.jpg',
#    'release_date': '2020-10-02',
#    'title': 'Nishabdham',
#    'video': False,
#    'vote_average': 5.8,
#    'vote_count': 5},
#   {'adult': False,
#    'backdrop_path': '/dIvfMOPSLWiTPWU4iN94Vtn6XNN.jpg',
#    'genre_ids': [27, 14, 9648],
#    'id': 461649,
#    'original_language': 'hi',
#    'original_title': 'परी',
#    'overview': 'Arnab tries to help Ruksahana, who is found under mysterious circumstances in a house. He lets her stay at his home until he discovers something strange about her.',
#    'popularity': 3.983,
#    'poster_path': '/togwv0TGqXkIA2YuYIY9VDLEkdF.jpg',
#    'release_date': '2018-03-02',
#    'title': 'Pari',
#    'video': False,
#    'vote_average': 6.5,
#    'vote_count': 28},
#   {'adult': False,
#    'backdrop_path': '/opc1eeUJkPuEPpoLFxkVOaXs6CO.jpg',
#    'genre_ids': [27, 18, 53],
#    'id': 744876,
#    'original_language': 'hi',
#    'original_title': 'काली खुहि',
#    'overview': "When a restless spirit curses a Punjab village that has a history of female infanticide, the town's fate lies in the hands of a 10-year old girl, Shivangi.",
#    'popularity': 3.726,
#    'poster_path': '/fPlZQUXQrAa2dG3zluXgqhOqdin.jpg',
#    'release_date': '2020-10-30',
#    'title': 'Kaali Khuhi',
#    'video': False,
#    'vote_average': 4.4,
#    'vote_count': 10},
#   {'adult': False,
#    'backdrop_path': '/mZ8Zba9P0LHr37p98I11WVxs0d6.jpg',
#    'genre_ids': [80, 27, 9648, 53],
#    'id': 397490,
#    'original_language': 'kn',
#    'original_title': 'ಮಗಳು ಜಾನಕಿ',
#    'overview': 'A journalist who intents to write an article on traffic rule breakers gets dragged into a whirlpool of murder cases and deception.',
#    'popularity': 3.59,
#    'poster_path': '/fjl9czd3zj0QpeaXAysAGwM9UrD.jpg',
#    'release_date': '2016-05-20',
#    'title': 'U Turn',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 27},
#   {'adult': False,
#    'backdrop_path': '/1Tpdv2bbpU3cwUF1HwFgQUejOYJ.jpg',
#    'genre_ids': [35, 27],
#    'id': 408475,
#    'original_language': 'ta',
#    'original_title': 'தேவி',
#    'overview': 'A man who wants a modern girl for a wife unwillingly marries a village girl. What happens when the girl is possessed by the ghost of an aspiring actress?',
#    'popularity': 3.333,
#    'poster_path': '/wtsZFBBPH5Y8GEnTPDoHYxWObz8.jpg',
#    'release_date': '2016-10-07',
#    'title': 'Devi(L)',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 15}],
#  'total_pages': 23,
#  'total_results': 450}

# %%
# in this dataset, the data to extract is under 'features'
df = pd.json_normalize(data, 'results')
df['cast']=np.nan

df
# Out:
#     adult                     backdrop_path           genre_ids      id  \
# 0   False  /kIszdVMM7Dezzrs0P7jUcMkG3o8.jpg            [27, 14]  714338
# 1   False  /dKSykSoV8eGWYqgmVJwBpBvTPzz.jpg                [27]  601643
# 2   False  /eJPky5hssaNpjVRS5XMB3gkgJrQ.jpg            [27, 35]  533991
# 3   False  /lDiRA1SkMLVduOaOmn6V0vg3c0h.jpg        [35, 27, 53]   19025
# 4   False  /ndO0KTkql6zr0u0cQ6gOsqpgpUd.jpg            [27, 14]  538858
# 5   False                              None            [35, 27]  191562
# 6   False  /hbVQ8B6k1XyRCa1aGQluyyT4LOX.jpg            [27, 53]  616880
# 7   False                              None            [35, 27]  330425
# 8   False  /2JTqYozAkCUga9LSq64gI9CJ8Bm.jpg    [35, 27, 28, 14]  472123
# 9   False  /2pGBScm9WFQhDRL0ZljVgbWdhWP.jpg      [18, 9648, 27]   19950
# 10  False  /lHyphBOFj1gv2Ykg5dmRtxWx92M.jpg            [27, 53]  553456
# 11  False  /xbRIRQKKGJHEUB45AEH39ZCZNda.jpg  [14, 27, 9648, 53]   84368
# 12  False  /yCNnj1s6CoAOehejo27TV8gtOKe.jpg            [27, 35]  603673
# 13  False  /iWpsVDT36YxGxxf23DUEwiHSBe0.jpg        [14, 27, 53]   47655
# 14  False  /7GuYHiwBEnZ6ulinOOJAHLjlYRE.jpg            [14, 27]  371420
# 15  False  /qQGKo21qes7ZjsJqKSSnfUBghKM.jpg            [53, 27]  648705
# 16  False  /dIvfMOPSLWiTPWU4iN94Vtn6XNN.jpg      [27, 14, 9648]  461649
# 17  False  /opc1eeUJkPuEPpoLFxkVOaXs6CO.jpg        [27, 18, 53]  744876
# 18  False  /mZ8Zba9P0LHr37p98I11WVxs0d6.jpg  [80, 27, 9648, 53]  397490
# 19  False  /1Tpdv2bbpU3cwUF1HwFgQUejOYJ.jpg            [35, 27]  408475
#
#    original_language                      original_title  \
# 0                 hi                             Bulbbul
# 1                 hi                       Ghost Stories
# 2                 hi                              स्त्री
# 3                 hi                          भूल भुलैया
# 4                 hi                             तुम्बाड
# 5                 hi                          गो गोआ गॉन
# 6                 hi  Bhoot: Part One - The Haunted Ship
# 7                 ta                           காஞ்சனா 2
# 8                 hi                         गोलमाल अगेन
# 9                 ta                        யாவரும் நலம்
# 10                ta                           கேம் ஓவர்
# 11                ml                    മണിച്ചിത്രത്താഴ്
# 12                hi                             लक्ष्मी
# 13                hi                               Hisss
# 14                ta                            காஷ்மோரா
# 15                te                           నిశ్శబ్దం
# 16                hi                                 परी
# 17                hi                           काली खुहि
# 18                kn                          ಮಗಳು ಜಾನಕಿ
# 19                ta                                தேவி
#
#                                              overview  popularity  \
# 0   A child bride grows up to be an enigmatic woma...      27.028
# 1            An anthology of four short horror tales.       8.424
# 2   Set in the town of Chanderi, Stree is based on...       7.421
# 3   When U.S.-based Siddharth visits his Indian ho...       6.864
# 4   India, 1918. On the outskirts of Tumbbad, a cu...       6.267
# 5   A rave party off the coast of Goa goes horrify...       4.930
# 6   When an abandoned haunted ship called 'Sea Bir...       4.693
# 7   A TV channel’s crew goes to a deserted beachsi...       4.609
# 8   Gopal and his best friends are back again, and...       4.463
# 9   Manohar, an upwardly mobile middle class India...       4.427
# 10  Swapna, a nyctophobic game designer, is on a t...       4.406
# 11  A young couple, Ganga and Nakulan, arrives at ...       4.388
# 12  Aasif's belief in logic and science shatters w...       4.180
# 13  Based on the Far Eastern myth of the snake wom...       4.169
# 14  Kaashmora, a present era black magic specialis...       4.028
# 15  Seattle PD is investigating the murder of a ma...       4.010
# 16  Arnab tries to help Ruksahana, who is found un...       3.983
# 17  When a restless spirit curses a Punjab village...       3.726
# 18  A journalist who intents to write an article o...       3.590
# 19  A man who wants a modern girl for a wife unwil...       3.333
#
#                          poster_path release_date  \
# 0   /4XYEqHqvcf6vxFhNyeKZz5xbUfV.jpg   2020-06-24
# 1   /wuTwPYFoEGQG3EntpdZA8LlBBdx.jpg   2020-01-01
# 2    /vkbSB8U9uPN18ssXCf8taetBae.jpg   2018-08-31
# 3   /soRW3p4GlPphHiFkwbqYGrodQ5S.jpg   2007-10-12
# 4   /5Q3Iz5YaGZVnvk3tjDDrW71iaym.jpg   2018-10-12
# 5   /5yArWoxijgN0gvo0ExQfKXgZ0Qr.jpg   2013-05-10
# 6   /5rSRVvlIlelgKM58MAnnk4FId86.jpg   2020-02-21
# 7   /oBaVzegjQza23C1XCOMfnQRhplw.jpg   2015-04-17
# 8   /kGx26PL1v658T8XbOk5MfmNpHU3.jpg   2017-10-20
# 9   /pb1Dm4lKpqdqXdsX1piIIiTaTGj.jpg   2009-03-06
# 10  /wBUt6oTFZOMN1skbhIq0gpxpe6J.jpg   2019-06-14
# 11  /5YccrqvJFTfAVyEZp08I3fLx15y.jpg   1993-12-25
# 12  /9sZ1UGVxOCs4yDd5NoACRkK0oXn.jpg   2020-11-09
# 13  /iSCkImhJUgyagR7FxXxasXnNsDv.jpg   2010-10-22
# 14  /fhWdd4obIA9ASc7xYfo38JyLqpQ.jpg   2016-10-28
# 15  /mz4hwTvyU4AERcgZxY1rpL2A8sv.jpg   2020-10-02
# 16  /togwv0TGqXkIA2YuYIY9VDLEkdF.jpg   2018-03-02
# 17  /fPlZQUXQrAa2dG3zluXgqhOqdin.jpg   2020-10-30
# 18  /fjl9czd3zj0QpeaXAysAGwM9UrD.jpg   2016-05-20
# 19  /wtsZFBBPH5Y8GEnTPDoHYxWObz8.jpg   2016-10-07
#
#                                  title  video  vote_average  vote_count  cast
# 0                              Bulbbul  False           6.9          57   NaN
# 1                        Ghost Stories  False           4.7          38   NaN
# 2                                Stree  False           7.0          80   NaN
# 3                      Bhool Bhulaiyaa  False           6.4          96   NaN
# 4                              Tumbbad  False           7.7         105   NaN
# 5                          Go Goa Gone  False           5.8          68   NaN
# 6   Bhoot: Part One - The Haunted Ship  False           6.6          15   NaN
# 7                           Kanchana 2  False           5.7          17   NaN
# 8                        Golmaal Again  False           5.5          57   NaN
# 9                        Yavarum Nalam  False           6.1          46   NaN
# 10                           Game Over  False           6.3          39   NaN
# 11                    Manichitrathazhu  False           7.6          52   NaN
# 12                              Laxmii  False           6.8          11   NaN
# 13                               Hisss  False           3.7          26   NaN
# 14                           Kaashmora  False           4.8          17   NaN
# 15                          Nishabdham  False           5.8           5   NaN
# 16                                Pari  False           6.5          28   NaN
# 17                         Kaali Khuhi  False           4.4          10   NaN
# 18                              U Turn  False           6.8          27   NaN
# 19                             Devi(L)  False           5.7          15   NaN

# %%
movie_id=df['id']
list1=[]

for i in range(movie_id.size):
    http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
    url = 'https://api.themoviedb.org/3/movie/'+str(movie_id[i])+'/credits?api_key=d08aea0bd49352097d28659b824a26b6&language=en-US'
    r= http.request('GET', url)
    data1 = json.loads(r.data.decode('utf-8'))
    df1 = pd.json_normalize(data1, 'cast')
    list1.append(df1['name'].tolist())
    df['cast'][i]=list1[i]
    
df1.head()
# Out:
# <ipython-input-12-a25926fb0506>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cast'][i]=list1[i]
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#    adult  gender      id known_for_department            name   original_name  \
# 0  False       1   85721               Acting  Tamanna Bhatia  Tamanna Bhatia
# 1  False       2   89154               Acting     Prabhu Deva     Prabhu Deva
# 2  False       2   95750               Acting       Sonu Sood       Sonu Sood
# 3  False       2   85588               Acting    Murli Sharma    Murli Sharma
# 4  False       1  130110               Acting     Amy Jackson     Amy Jackson
#
#    popularity                      profile_path  cast_id  \
# 0       2.136  /ytwRvy53dH9KrpTcZu5GsNi4HnE.jpg        1
# 1       0.732  /lfVxoyweEPkIu6zFa44ajPuSJA1.jpg        0
# 2       1.400  /vViZnWuG9VQk2IT3vWSRd70m56U.jpg        2
# 3       1.620  /zk27o2jYK293oRObr5kL5W9v0p0.jpg        4
# 4       1.400  /qMWitVFeHAfDTZWcChsWFtBdYap.jpg       33
#
#                                 character                 credit_id  order
# 0                             Devi / Ruby  5799f79fc3a368251b003256      0
# 1                           Krishna Kumar  5799f79392514112fb0015d4      1
# 2                              Raj Khanna  5799f7a7c3a36821d300313c      2
# 3                                   Dilip  5799f7d2c3a3682d4f0034f3      3
# 4  Special Appearance in "Char Maar" Song  57ffc2ecc3a3681552000f4f      5

# %%
df.head()
# Out:
#    adult                     backdrop_path     genre_ids      id  \
# 0  False  /kIszdVMM7Dezzrs0P7jUcMkG3o8.jpg      [27, 14]  714338
# 1  False  /dKSykSoV8eGWYqgmVJwBpBvTPzz.jpg          [27]  601643
# 2  False  /eJPky5hssaNpjVRS5XMB3gkgJrQ.jpg      [27, 35]  533991
# 3  False  /lDiRA1SkMLVduOaOmn6V0vg3c0h.jpg  [35, 27, 53]   19025
# 4  False  /ndO0KTkql6zr0u0cQ6gOsqpgpUd.jpg      [27, 14]  538858
#
#   original_language original_title  \
# 0                hi        Bulbbul
# 1                hi  Ghost Stories
# 2                hi         स्त्री
# 3                hi     भूल भुलैया
# 4                hi        तुम्बाड
#
#                                             overview  popularity  \
# 0  A child bride grows up to be an enigmatic woma...      27.028
# 1           An anthology of four short horror tales.       8.424
# 2  Set in the town of Chanderi, Stree is based on...       7.421
# 3  When U.S.-based Siddharth visits his Indian ho...       6.864
# 4  India, 1918. On the outskirts of Tumbbad, a cu...       6.267
#
#                         poster_path release_date            title  video  \
# 0  /4XYEqHqvcf6vxFhNyeKZz5xbUfV.jpg   2020-06-24          Bulbbul  False
# 1  /wuTwPYFoEGQG3EntpdZA8LlBBdx.jpg   2020-01-01    Ghost Stories  False
# 2   /vkbSB8U9uPN18ssXCf8taetBae.jpg   2018-08-31            Stree  False
# 3  /soRW3p4GlPphHiFkwbqYGrodQ5S.jpg   2007-10-12  Bhool Bhulaiyaa  False
# 4  /5Q3Iz5YaGZVnvk3tjDDrW71iaym.jpg   2018-10-12          Tumbbad  False
#
#    vote_average  vote_count                                               cast
# 0           6.9          57  [Tripti Dimri, Rahul Bose, Avinash Tiwary, Par...
# 1           4.7          38  [Jhanvi Kapoor, Surekha Sikri, Vijay Varma, So...
# 2           7.0          80  [Rajkummar Rao, Shraddha Kapoor, Pankaj Tripat...
# 3           6.4          96  [Akshay Kumar, Vidya Balan, Ameesha Patel, Shi...
# 4           7.7         105  [Sohum Shah, Mohammad Samad, Jyoti Malshe, Dhu...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval

# %%
df = df.drop(['original_language'],axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-12b08d4f26df> in <module>
# ----> 1 df = df.drop(['original_language'],axis=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['original_language'] not found in axis"

# %%
df.to_csv('movie_data.csv.zip', index = False)

# %%
import pandas as pd
import scipy.sparse as sp
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def get_data():
        movie_data = pd.read_csv('dataset/movie_data.csv.zip')
        movie_data['original_title'] = movie_data['original_title'].str.lower()
        return movie_data

def combine_data(data):
        data_recommend = data.drop(columns=['movie_id', 'original_title','plot'])
        data_recommend['combine'] = data_recommend[data_recommend.columns[0:2]].apply(
                                                                        lambda x: ','.join(x.dropna().astype(str)),axis=1)
        
        data_recommend = data_recommend.drop(columns=[ 'cast','genres'])
        return data_recommend
        
def transform_data(data_combine, data_plot):
        count = CountVectorizer(stop_words='english')
        count_matrix = count.fit_transform(data_combine['combine'])

        tfidf = TfidfVectorizer(stop_words='english')
        tfidf_matrix = tfidf.fit_transform(data_plot['plot'])

        combine_sparse = sp.hstack([count_matrix, tfidf_matrix], format='csr')
        cosine_sim = cosine_similarity(combine_sparse, combine_sparse)
        
        return cosine_sim


def recommend_movies(title, data, combine, transform):
        indices = pd.Series(data.index, index = data['original_title'])
        index = indices[title]



        sim_scores = list(enumerate(transform[index]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        sim_scores = sim_scores[1:21]


        movie_indices = [i[0] for i in sim_scores]

        movie_id = data['movie_id'].iloc[movie_indices]
        movie_title = data['original_title'].iloc[movie_indices]
        movie_genres = data['genres'].iloc[movie_indices]

        recommendation_data = pd.DataFrame(columns=['Movie_Id','Name', 'Genres'])

        recommendation_data['Movie_Id'] = movie_id
        recommendation_data['Name'] = movie_title
        recommendation_data['Genres'] = movie_genres

        return recommendation_data

def results(movie_name):
        movie_name = movie_name.lower()

        find_movie = get_data()
        combine_result = combine_data(find_movie)
        transform_result = transform_data(combine_result,find_movie)

        if movie_name not in find_movie['original_title'].unique():
                return 'Movie not in Database'

        else:
                recommendations = recommend_movies(movie_name, find_movie, combine_result, transform_result)
                return recommendations.to_dict('records')
